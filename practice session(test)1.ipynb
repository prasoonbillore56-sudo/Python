# %% [markdown]
# 31-01-2026
# practice test 1

# %%
print(10+5*2)
# Out:
# 20

# %%
print((10+5)*2)
# Out:
# 30

# %%
print (20-4**2)
# Out:
# 4

# %%
print ( 100//5*2)
# Out:
# 40

# %%
print (18%5+2)
# Out:
# 5

# %%
print (2* (3**2))
# Out:
# 18

# %%
print (4*2**3 )
# Out:
# 32

# %%
print (16// 2**2 )
# Out:
# 4

# %%
print (9+6* 2**2 )
# Out:
# 33

# %%
print ( 8 -2 ** 2 * 2)
# Out:
# 0

# %%
print(10 > 5 and 5 > 2)
# Out:
# True

# %%
print(10 > 5 or 5 < 2)
# Out:
# True

# %%
print(not 10 > 5)
# Out:
# False

# %%
 print(True or False and False)
# Out:
# True

# %%
print(5 < 10 < 20)
# Out:
# True

# %%
x = 5
x += 3*2
print(x)
# Out:
# 11

# %%
x = 10
x *= 2 + 3 
print(x)
# Out:
# 50

# %%
x = 5
x = x == 5
print(x)
# Out:
# True

# %%
x = 2 
x **= 2 + 1
print(x)
# Out:
# 8

# %%
x = 1 
x += x == 1
print(x)
# Out:
# 2

# %%
 print(5 and 0 or 8)
# Out:
# 8

# %%
print(0 or 5 and 8)
# Out:
# 8

# %%
print(True == False or True)
# Out:
# True

# %%
 print(False == False and False)
# Out:
# False

# %%
 print(not True == False)
# Out:
# True

# %%
1. #*WAP to check if a given character is present in a string entered by the user.*


str = input("enter a string")
char = input("Enter a character")
print(char)
# Out:
# enter a string hello
# Enter a character e
# e

# %%
#*WAP to check if a given number is in a predefined list of prime numbers.*
primes = [2, 3, 5, 7, 11]

num = int(input("enter the number"))

if num in primes:
    print("Present")
else:
    print("Not Present")
# Out:
# enter the number 7
# Present

# %%
#*WAP to check if a user's chosen username is already in a list of existing usernames.*
existing = ["alice", "bob", "john123"]
username = ("john123")

if username in existing:
    print("username already taken")
else:
    print("invalid username")
# Out:
# username already taken

# %%
#*WAP to check if a word is part of a given sentence (input both word and ser ence).*
sentence = input("enter the sentence")
word = input("enter the word")

if word in sentence:
    print("Word is present in the sentence")
else:
    print("Word is NOT present in the sentence")
# Out:
# enter the sentence the sun rises in the east
# enter the word sun
# Word is present in the sentence

# %%
#**WAP to check if two variables refer to the same object in memory.**
a = (1,2)
b = a 
if a is b:
    print("a and b refers to the same object")
# Out:
# a and b refers to the same object

# %%
#**WAP to input two lists and check if they are the same object or different objects.**

list1 = (1,2,3)
list2 = (1,2,3)

if list1 is list2:
    print("list1 and list2 refers to the same object")
else:
    print("list1 and list2 not refers to the same object")
# Out:
# list1 and list2 not refers to the same object

# %%
#"WAP to check if a variable is 'None and print a message if it is.**

var = None 
if var is None:
    print("the variable is none")
# Out:
# the variable is none

# %%
#"WAP to check if a user's input is not 'None and proceed only if it is not.**
var = "Hello"
if var is not None:
    print("the variable is not none")
# Out:
# the variable is not none

# %%
#**WAP to compare two strings and check if they are the same object or just equal in value.**

str1 = "apple" 
str2 = "".join(["a","p","p","l","e"])
if str1 in str2:
    print("str1 and str2 have same value but are not the same object")
else:
    print("different values")
# Out:
# str1 and str2 have same value but are not the same object
