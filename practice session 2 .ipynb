# %%
s = "Pythonista"
result = s[1:6]
print(result)
# Out:
# ython

# %%
s = "Development"
print(s[::2])
# Out:
# Dvlpet

# %%
#Reverse the string "Analytics" using slicing.
s = "Analytics"
reverse = s[::-1]
print(reverse)
# Out:
# scitylanA

# %%
#Extract the last 4 characters from "Analytics".
s = "Analytics"
print(s[-4:])
# Out:
# tics

# %%
#Extract "Sci" from "DataScience" using negative indices.
s = "DataScience"
print(s[-7:-4])
# Out:
# Sci

# %%
#What is the result of "Engineering"[-6:-2]
s = "Engineering"
print(s[-6:-2])
# Out:
# eeri

# %%
#slice and return "eering" from "Engineering" using positive indices
s = "Engineering"
print(s[5:11])
# Out:
# eering
