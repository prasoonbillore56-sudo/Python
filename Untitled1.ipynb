# %%
#how to print A A A B B B C C C C

for i in range(2):
    print("A", end = " ")
for i in range(3):
    print("B", end = " ")
for i in range(4):
    print("C", end = " ")
# Out:
# A A B B B C C C C

# %%
print("star pattern")
for i in range(5,0,-1):
    print("*" * i)
# Out:
# star pattern
# *****
# ****
# ***
# **
# *

# %%
s = "news"
for i in s:
    if i == "nN":
        print(i,"North")
    elif i == 'eE':
        print(i,"East")
    elif i == 'wW':
        print(i,"West")
    elif i == 'sS':
        print(i,"South")

# %%
#find no. of vowels and consonents in a string: "Hello How Are You"
