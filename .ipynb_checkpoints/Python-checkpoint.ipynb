# %%
print("hello world")
# Out:
# hello world

# %%
#type conversion
#int --> float, bool, str, complex
a = 100
b = float(a)
print(b)
print(type(b))
# Out:
# 100.0
# <class 'float'>

# %%
a = 100
b = bool(a)
print(b)
print(type(b))
# Out:
# True
# <class 'bool'>

# %%
a = 100
b = str(a)
print(b)
print(type(b))
# Out:
# 100
# <class 'str'>

# %%
a = 100
b = complex(a)
print(b)
print(type(b))
# Out:
# (100+0j)
# <class 'complex'>

# %%
##float --> int, bool, str, complex
a = 99.99
b = int(a)
print(b)
print(type(b))
# Out:
# 99
# <class 'int'>

# %%
a = 99.99
b = bool(a)
print(b)
print(type(b))
# Out:
# True
# <class 'bool'>

# %%
a = 99.99
b = str(a)
print(b)
print(type(b))
# Out:
# 99.99
# <class 'str'>

# %%
a = 99.99
b = complex(a)
print(b)
print(type(b))
# Out:
# (99.99+0j)
# <class 'complex'>

# %%
# bool --> int, float, str, complex
a = True
b = int(a)
print(b)
print(type(b))
# Out:
# 1
# <class 'int'>

# %%
a = True 
b = float(a)
print(b)
print(type(b))
# Out:
# 1.0
# <class 'float'>

# %%
a = True
b = str(a)
print(b)
print(type(b))
# Out:
# True
# <class 'str'>

# %%
a = True
b = complex(a)
print(b)
print(type(b))
# Out:
# (1+0j)
# <class 'complex'>

# %%
a = False
b = int(a)
print(b)
print(type(b))
# Out:
# 0
# <class 'int'>

# %%
a = False
b = complex(a)
print(b)
print(type(b))
# Out:
# 0j
# <class 'complex'>

# %%
# str --> int, float, bool, complex
a = "50"
b = int(a)
print(b)
print(type(b))
# Out:
# 50
# <class 'int'>

# %%
a = "50"
b = float(a)
print(b)
print(type(b))
# Out:
# 50.0
# <class 'float'>

# %%
a = "50"
b = bool(a)
print(b)
print(type(b))
# Out:
# True
# <class 'bool'>

# %%
a = "50"
b = bool(a)
print(b)
print(type(b))
# Out:
# True
# <class 'bool'>

# %%
a = "50"
b = complex(a)
print(b)
print(type(b))
# Out:
# (50+0j)
# <class 'complex'>

# %%
# compex --> int, float, bool, str
a = 31+8j
b = int(a)
print(b)
print(type(b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 # compex --> int, float, bool, str
#       2 a = 31+8j
# ----> 3 b = int(a)
#       4 print(b)
#       5 print(type(b))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
a = 31+8j
b = float(a)
print(b)
print(type(b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 a = 31+8j
# ----> 2 b = float(a)
#       3 print(b)
#       4 print(type(b))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
a = 31+8j
b = bool(a)
print(b)
print(type(b))
# Out:
# True
# <class 'bool'>

# %%
a = 31+8j
b = str(a)
print(b)
print(type(b))
# Out:
# (31+8j)
# <class 'str'>

# %%
#Print the below words in each line using a single print function
  # Python
  # is 
  # Fun
print("Python\nis\nFun")
# Out:
# Python
# is
# Fun

# %%
#Create variables of the following types and print them with their types:Integer, Float, String, Boolean, Complex number.
a = 50
b = 0.78
c = "ronaldo"
d = False
e = 50+5j
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
print(e,type(e))
# Out:
# 50 <class 'int'>
# 0.78 <class 'float'>
# ronaldo <class 'str'>
# False <class 'bool'>
# (50+5j) <class 'complex'>

# %%
 #Write a program that checks the type of: x = True, y = None
x = True
y = None
print(x,type(x))
print(y,type(y))
# Out:
# True <class 'bool'>
# None <class 'NoneType'>

# %%
#Store your roll number and percentage, then print them in one line.
roll_no = 43
percentage = "89.9%"
print("roll no.:",roll_no,"percentage:",percentage)
# Out:
# roll no.: 43 percentage: 89.9%

# %%
#Predict the output:  print(type(type(5)))
print(type(type(5)))
# Out:
# <class 'type'>

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
import random

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
a = random.randint(1,6)
print(a)
# Out:
# 6

# %%
help(random.random)
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).

# %%
a = random.random()
print(a)
# Out:
# 0.09848461964724398

# %%
#[ = include 
#) = exclude

# %%
import math

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
help(math.factorial)
# Out:
# Help on built-in function factorial in module math:
#
# factorial(n, /)
#     Find n!.

# %%
a = math.factorial(6)
print(a)
# Out:
# 720

# %%
a = math.factorial(4)
b = math.factorial(3)
c = a/b
print(c)
# Out:
# 4.0

# %%
help(math.pow)
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
a = pow(3,8)
print(a)
# Out:
# 6561

# %%
#h.w 
#explore Pi 
#reminder
#sin
#tan
#log
#floor
#ceil

# %%
import math as mt

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import keyword

# %% [raw]
# dir(keyword)

# %%
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
#name = 'PYTHON" --> ASSIGN 
#NAME == 'python" --> CONDITION # BARABAR HAI YA NHI

# %%
Registered_No = 101
input = int(input("enter the registered no."))

if Registered_No == input:
      print("Your Password is correct")
# Out:
# enter the registered no. 101
# Your Password is correct

# %% [markdown]
# # IF, IF ,ELSE , ELIF, ELSE

# %%
a = 1014
b = 1014
if a==b:
    print("correct password")
else:
    print("incorrect password")

print("program end")

# %%
a = 1014
b = int(input("enter your Password"))
if a==b:
    print("correct password")
else:
    print("incorrect password")

print("program end")
# Out:
# enter your Password 1014
# correct password
# program end

# %%
a = int(input("enter the first no."))
b = int(input("enter the second no."))
if a > b:
    print(a,"is greater than",b)
else :
    print(a, "is smaller than",b)
# Out:
# enter the first no. 50
# enter the second no. 80
# 50 is smaller than 80

# %%
a = eval(input("enter the number"))
if a>0 :
    print("number {} is positive".format(a))
elif a<0 :
    print("number {} is negative".format(a))
else:
    print("number {} is neutral".format(a))
# Out:
# enter the number 2
# number 2 is positive

# %%
#WAP ask user to enter distance in km
#if dist is more than 10km : print charge is 100rs 
#if dist is btw 7 to 10km : print charge is 70rs 
#if dist is btw 4 to 7km : print charge is 40rs 
#otherwise print charge is 30rs 

dist = eval(input("enter Distance in km: "))
if dist> 10:
    print("charge is 100rs") 
elif dist > 7 and dist <= 10:
    print("charge is 70rs")
elif dist > 4 and dist <= 7:
    print("charge is 40rs")
else:
    print("charge is 30rs")
# Out:
# enter Distance in km:  70
# charge is 100rs

# %%
# WAP ask the user enter salary 
# if salary> 10 Lks:
# ask user to enter the user tax percentages: 10% 
# print : the amount of tax paid: (salary*tax_per)/100
#if salary btw 7 to 10 Laks 
# ask user to enter the user tax percentages: 5%
# print :the amount of tax paid
#if salary btw 4 to 7 Laks
# ask user to enter the user tax percentages: 2.5%
# print :the amount of tax paid
#otherwise : print("No tax required")

sal = int(input("enter the salary"))
tax_per = float(input("tax percentages:"))
total_amt = (sal*tax_per)/100
if sal >1000000:
    print("the amount of tax paid" , total_amt)
elif sal > 700000 and sal <= 1000000:
    print("the amount of tax paid" , total_amt)
elif sal > 400000 and sal <= 700000:
     print("the amount of tax paid" , total_amt)
else:
    print("no tax required")
# Out:
# enter the salary 865000
# tax percentages: 5
# the amount of tax paid 43250.0
