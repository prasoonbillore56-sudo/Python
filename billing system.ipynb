# %%
name1 = input("enter name of the first product: ")
pr1 = float(input("enter price of the product"))
q1 = int(input("enter quantity : "))
name2 = input("enter name of the second product: ")
pr2 = float(input("enter price of the product"))
q1 = int(input("enter quantity : "))
name3 = input("enter name of the third product: ")
pr3 = float(input("enter price of the product"))
q1 = int(input("enter quantity : "))
name4 = input("enter name of the fourth product: ")
pr4 = float(input("enter price of the product"))
q1 = int(input("enter quantity : "))
name5 = input("enter name of the fifth product: ")
pr5 = float(input("enter price of the product"))
q1 = int(input("enter quantity : "))
print()
price1 = pr1*q1
price2 = pr2*q2
price3 = pr3*q3
price4 = pr4*q4
price5 = pr5*q5
add = price1+price2+price3+price4+price5
#gst calculation @18%
cgst = add * 0.09
sgst = add * 0.09
gst_total = cgst + sgst
final_price = add + gst_total
print()

print("                    DigiHEAVEN COMPUTERS ")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -")

print("Product Name                                        Qty               Price")
print("-----------------------------------------------------------------------------")
print()
print(f"  {name1}                                         {qty1}             {pr1}")
print(f"  {name2}                                         {qty2}             {pr2}")
print(f"  {name3}                                         {qty3}             {pr3}")
print(f"  {name4}                                         {qty4}             {pr4}")
print(f"  {name5}                                         {qty5}             {pr5}")
print("-----------------------------------------------------------------------------")
print()
print("Total Quantity :     {total_qty")
print(f"Total Price :  {total_price:.2f}"
print()      
print("-----------------------------------------------------------------------------")

print("GST Details")
print("- - - - - - - - - - - - - - - - - - - - - - -")
print(f"CGST (9%) : {cgst:.2f}:")
print(f"SGST (9%) : {sgst:.2f}:")
print("-----------------------------------------------------------------------------")
print()
print(f"Price After GST : {final_Price:.2f}") 
print("-----------------------------------------------------------------------------")
print()
print()
print("                         THANK YOU - VISIT AGAIN")
# Out:
#                     DigiHEAVEN COMPUTERS
# -----------------------------------------------------
# enter name of the first product:  RTX 6050
# enter price of the product 169000
# enter name of the second product:  RHH
# enter price of the product 9774
# enter name of the third product:  ERGDFGVBDF
# enter price of the product 5443
# enter name of the fourth product:  FDGDT
# enter price of the product 4436
# enter name of the fifth product:  HGFND
# enter price of the product 747
# Product Name                                Price
# -----------------------------------------------------
#
#   RTX 6050                                   169000.0
#   RHH                                   9774.0
#   ERGDFGVBDF                                   5443.0
#   FDGDT                                   4436.0
#   HGFND                                   747.0
# -----------------------------------------------------
#
# Total Quantity :     5
# Total Price :  189400.0
#
# GST Details
# ...

# %%
name1 = input("enter name of the first product: ")
pr1 = float(input("enter price of the product"))
qty1 = int(input("enter quantity : "))
name2 = input("enter name of the second product: ")
pr2 = float(input("enter price of the product"))
qty2 = int(input("enter quantity : "))
name3 = input("enter name of the third product: ")
pr3 = float(input("enter price of the product"))
qty3 = int(input("enter quantity : "))
name4 = input("enter name of the fourth product: ")
pr4 = float(input("enter price of the product"))
qty4 = int(input("enter quantity : "))
name5 = input("enter name of the fifth product: ")
pr5 = float(input("enter price of the product"))
qty5 = int(input("enter quantity : "))
print()
price1 = pr1*q1
price2 = pr2*q2
price3 = pr3*q3
price4 = pr4*q4
price5 = pr5*q5
add = price1+price2+price3+price4+price5
#gst calculation @18%
cgst = add * 0.09
sgst = add * 0.09
gst_total = cgst + sgst
final_price = add + gst_total
print()

print("                    DigiHEAVEN COMPUTERS ")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -")

print("Product Name                                        Qty               Price")
print("-----------------------------------------------------------------------------")
print()
print(f"  {name1}                                         {qty1}             {pr1}")
print(f"  {name2}                                         {qty2}             {pr2}")
print(f"  {name3}                                         {qty3}             {pr3}")
print(f"  {name4}                                         {qty4}             {pr4}")
print(f"  {name5}                                         {qty5}             {pr5}")
print("-----------------------------------------------------------------------------")
print()
print("Total Quantity :     {total_qty")
print(f"Total Price :  {total_price:.2f}")
print()      
print("-----------------------------------------------------------------------------")

print("GST Details")
print("- - - - - - - - - - - - - - - - - - - - - - -")
print(f"CGST (9%) : {cgst:.2f}:")
print(f"SGST (9%) : {sgst:.2f}:")
print("-----------------------------------------------------------------------------")
print()
print(f"Price After GST : {final_Price:.2f}") 
print("-----------------------------------------------------------------------------")
print()
print()
print("                         THANK YOU - VISIT AGAIN")
# Out:
# enter name of the first product:  NVIDIA GEFORCE RTX 5090
# enter price of the product 160658.89
# enter quantity :  1
# enter name of the second product:  ASUS LPDDR5 RAM
# enter price of the product 56430
# enter quantity :  2
# enter name of the third product:  ASUS MOTHERBOARD
# enter price of the product 18540
# enter quantity :  1
# enter name of the fourth product:  INTEL I9 14TH GEN HX
# enter price of the product 32570
# enter quantity :  1
# enter name of the fifth product:  ASUS THUNDERBOLT COOL
# enter price of the product 15479.83
# enter quantity :  3
#                     DigiHEAVEN COMPUTERS
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Product Name                                        Qty               Price
# -----------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ...

# %%
name1 = input("enter name of the first product: ")
pr1 = float(input("enter price of the product: "))
q1 = int(input("enter quantity : "))
name2 = input("enter name of the second product: ")
pr2 = float(input("enter price of the product: "))
q2 = int(input("enter quantity : "))
name3 = input("enter name of the third product: ")
pr3 = float(input("enter price of the product: "))
q3 = int(input("enter quantity : "))
name4 = input("enter name of the fourth product: ")
pr4 = float(input("enter price of the product: "))
q4 = int(input("enter quantity : "))
name5 = input("enter name of the fifth product: ")
pr5 = float(input("enter price of the product: "))
q5 = int(input("enter quantity : "))
print()
price1 = pr1*q1
price2 = pr2*q2
price3 = pr3*q3
price4 = pr4*q4
price5 = pr5*q5
add = price1+price2+price3+price4+price5
#gst calculation @18%
cgst = add * 0.09
sgst = add * 0.09
gst_total = cgst + sgst
final_price = add + gst_total
total_qty = q1 + q2 + q3 + q4 + q5
total_price = add
print()

print("                    DigiHEAVEN COMPUTERS ")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -")

print("Product Name                                        Qty               Price")
print("-----------------------------------------------------------------------------")
print()
print(f"  {name1}                                         {q1}             {pr1}")
print(f"  {name2}                                         {q2}             {pr2}")
print(f"  {name3}                                         {q3}             {pr3}")
print(f"  {name4}                                         {q4}             {pr4}")
print(f"  {name5}                                         {q5}             {pr5}")
print("-----------------------------------------------------------------------------")
print()
print(f"Total Quantity :     {total_qty}")
print(f"Total Price :  {total_price:.2f}")
print()      
print("-----------------------------------------------------------------------------")

print("GST Details")
print("- - - - - - - - - - - - - - - - -")
print(f"CGST (9%) : {cgst:.2f}:")
print(f"SGST (9%) : {sgst:.2f}:")
print("-----------------------------------------------------------------------------")
print()
print(f"Price After GST : {final_price:.2f}") 
print("-----------------------------------------------------------------------------")
print()
print()
print("                         THANK YOU - VISIT AGAIN")
# Out:
# enter name of the first product:  NVIDIA GEFORCE RTX 5090
# enter price of the product:  167984.67
# enter quantity :  1
# enter name of the second product:  ASUS LPDDR5 RAM 32 GB
# enter price of the product:  56740
# enter quantity :  2
# enter name of the third product:  ASUS MOTHERBOARD
# enter price of the product:  18000
# enter quantity :  1
# enter name of the fourth product:  INTEL I9 14TH GEN HX
# enter price of the product:  40770.70
# enter quantity :  1
# enter name of the fifth product:  ASUS THUNDERBOLT COOL
# enter price of the product:  15789.74
# enter quantity :  3
#                     DigiHEAVEN COMPUTERS
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Product Name                                        Qty               Price
# -----------------------------------------------------------------------------
#
#   NVIDIA GEFORCE RTX 5090                                         1             167984.67
# ...
